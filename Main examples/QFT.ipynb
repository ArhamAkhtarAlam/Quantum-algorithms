# %%
# %pip install qiskit
from qiskit import *
from qiskit.visualization import plot_histogram, array_to_latex, plot_bloch_multivector
# %matplotlib inline
# %pip install 'qiskit>=2.1.0' 'qiskit-ibm-runtime>=0.40.1' 'qiskit-aer>=0.17.0' 'numpy' 'pylatexenc'
import numpy as np
from qiskit import QuantumCircuit
from qiskit.visualization import plot_histogram
from qiskit.circuit.library import QFTGate
# Out:
# Requirement already satisfied: qiskit in /usr/local/python/3.12.1/lib/python3.12/site-packages (2.2.3)
# Requirement already satisfied: rustworkx>=0.15.0 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from qiskit) (0.17.1)
# Requirement already satisfied: numpy<3,>=1.17 in /home/codespace/.local/lib/python3.12/site-packages (from qiskit) (2.3.1)
# Requirement already satisfied: scipy>=1.5 in /home/codespace/.local/lib/python3.12/site-packages (from qiskit) (1.16.0)
# Requirement already satisfied: dill>=0.3 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from qiskit) (0.4.0)
# Requirement already satisfied: stevedore>=3.0.0 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from qiskit) (5.5.0)
# Requirement already satisfied: typing-extensions in /home/codespace/.local/lib/python3.12/site-packages (from qiskit) (4.14.1)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: qiskit>=2.1.0 in /usr/local/python/3.12.1/lib/python3.12/site-packages (2.2.3)
# Requirement already satisfied: qiskit-ibm-runtime>=0.40.1 in /usr/local/python/3.12.1/lib/python3.12/site-packages (0.43.1)
# Requirement already satisfied: qiskit-aer>=0.17.0 in /usr/local/python/3.12.1/lib/python3.12/site-packages (0.17.2)
# Requirement already satisfied: numpy in /home/codespace/.local/lib/python3.12/site-packages (2.3.1)
# Requirement already satisfied: pylatexenc in /usr/local/python/3.12.1/lib/python3.12/site-packages (2.10)
# Requirement already satisfied: rustworkx>=0.15.0 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from qiskit>=2.1.0) (0.17.1)
# Requirement already satisfied: scipy>=1.5 in /home/codespace/.local/lib/python3.12/site-packages (from qiskit>=2.1.0) (1.16.0)
# Requirement already satisfied: dill>=0.3 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from qiskit>=2.1.0) (0.4.0)
# Requirement already satisfied: stevedore>=3.0.0 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from qiskit>=2.1.0) (5.5.0)
# Requirement already satisfied: typing-extensions in /home/codespace/.local/lib/python3.12/site-packages (from qiskit>=2.1.0) (4.14.1)
# Requirement already satisfied: requests>=2.19 in /home/codespace/.local/lib/python3.12/site-packages (from qiskit-ibm-runtime>=0.40.1) (2.32.4)
# Requirement already satisfied: requests-ntlm>=1.1.0 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from qiskit-ibm-runtime>=0.40.1) (1.3.0)
# Requirement already satisfied: urllib3>=1.21.1 in /home/codespace/.local/lib/python3.12/site-packages (from qiskit-ibm-runtime>=0.40.1) (2.5.0)
# Requirement already satisfied: python-dateutil>=2.8.0 in /home/codespace/.local/lib/python3.12/site-packages (from qiskit-ibm-runtime>=0.40.1) (2.9.0.post0)
# Requirement already satisfied: ibm-platform-services>=0.22.6 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from qiskit-ibm-runtime>=0.40.1) (0.71.0)
# Requirement already satisfied: pydantic>=2.5.0 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from qiskit-ibm-runtime>=0.40.1) (2.12.4)
# Requirement already satisfied: packaging in /home/codespace/.local/lib/python3.12/site-packages (from qiskit-ibm-runtime>=0.40.1) (25.0)
# Requirement already satisfied: psutil>=5 in /home/codespace/.local/lib/python3.12/site-packages (from qiskit-aer>=0.17.0) (7.0.0)
# Requirement already satisfied: ibm_cloud_sdk_core<4.0.0,>=3.24.2 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from ibm-platform-services>=0.22.6->qiskit-ibm-runtime>=0.40.1) (3.24.2)
# Requirement already satisfied: PyJWT<3.0.0,>=2.10.1 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from ibm_cloud_sdk_core<4.0.0,>=3.24.2->ibm-platform-services>=0.22.6->qiskit-ibm-runtime>=0.40.1) (2.10.1)
# Requirement already satisfied: six>=1.5 in /home/codespace/.local/lib/python3.12/site-packages (from python-dateutil>=2.8.0->qiskit-ibm-runtime>=0.40.1) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /home/codespace/.local/lib/python3.12/site-packages (from requests>=2.19->qiskit-ibm-runtime>=0.40.1) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /home/codespace/.local/lib/python3.12/site-packages (from requests>=2.19->qiskit-ibm-runtime>=0.40.1) (3.10)
# Requirement already satisfied: certifi>=2017.4.17 in /home/codespace/.local/lib/python3.12/site-packages (from requests>=2.19->qiskit-ibm-runtime>=0.40.1) (2025.7.9)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from pydantic>=2.5.0->qiskit-ibm-runtime>=0.40.1) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from pydantic>=2.5.0->qiskit-ibm-runtime>=0.40.1) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from pydantic>=2.5.0->qiskit-ibm-runtime>=0.40.1) (0.4.2)
# Requirement already satisfied: cryptography>=1.3 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from requests-ntlm>=1.1.0->qiskit-ibm-runtime>=0.40.1) (46.0.3)
# Requirement already satisfied: pyspnego>=0.4.0 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from requests-ntlm>=1.1.0->qiskit-ibm-runtime>=0.40.1) (0.12.0)
# Requirement already satisfied: cffi>=2.0.0 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from cryptography>=1.3->requests-ntlm>=1.1.0->qiskit-ibm-runtime>=0.40.1) (2.0.0)
# Requirement already satisfied: pycparser in /home/codespace/.local/lib/python3.12/site-packages (from cffi>=2.0.0->cryptography>=1.3->requests-ntlm>=1.1.0->qiskit-ibm-runtime>=0.40.1) (2.22)
# Note: you may need to restart the kernel to use updated packages.

# %%
qc=QuantumCircuit(3)
qc.compose(QFTGate(3), inplace=True)
qc.decompose().draw("mpl")
